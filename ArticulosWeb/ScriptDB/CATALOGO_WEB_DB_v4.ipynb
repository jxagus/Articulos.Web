-- %% [markdown]
-- # [CATALOGO_WEB_DB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [CATALOGO_WEB_DB]    Script Date: 8/8/2025 19:58:30 ******/
CREATE DATABASE [CATALOGO_WEB_DB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'CATALOGO_WEB_DB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\CATALOGO_WEB_DB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'CATALOGO_WEB_DB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\CATALOGO_WEB_DB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [CATALOGO_WEB_DB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET ARITHABORT OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET  MULTI_USER 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET QUERY_STORE = ON
GO
ALTER DATABASE [CATALOGO_WEB_DB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [Jxagus]

-- %%
USE [CATALOGO_WEB_DB]
GO

-- %%
/****** Object:  User [Jxagus]    Script Date: 8/8/2025 19:58:30 ******/
CREATE USER [Jxagus] FOR LOGIN [Jxagus] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %%
ALTER ROLE [db_owner] ADD MEMBER [Jxagus]
GO

-- %% [markdown]
-- # [dbo].[ARTICULOS]

-- %%
/****** Object:  Table [dbo].[ARTICULOS]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ARTICULOS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [varchar](50) NULL,
	[Nombre] [varchar](50) NULL,
	[Descripcion] [varchar](150) NULL,
	[IdMarca] [int] NULL,
	[IdCategoria] [int] NULL,
	[ImagenUrl] [varchar](1000) NULL,
	[Precio] [money] NULL,
	[Stock] [int] NOT NULL,
	[PorcentajeDescuento] [int] NULL,
	[PrecioDescuento] [decimal](18, 2) NULL,
	[FechaCreacion] [datetime] NULL,
 CONSTRAINT [PK_ARTICULOS] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CATEGORIAS]

-- %%
/****** Object:  Table [dbo].[CATEGORIAS]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CATEGORIAS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [varchar](50) NULL,
 CONSTRAINT [PK_CATEGORIAS] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FAVORITOS]

-- %%
/****** Object:  Table [dbo].[FAVORITOS]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FAVORITOS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdUser] [int] NOT NULL,
	[IdArticulo] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MARCAS]

-- %%
/****** Object:  Table [dbo].[MARCAS]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MARCAS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [varchar](50) NULL,
 CONSTRAINT [PK_MARCAS] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MovimientosStock]

-- %%
/****** Object:  Table [dbo].[MovimientosStock]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MovimientosStock](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdArticulo] [int] NULL,
	[Fecha] [datetime] NULL,
	[Cantidad] [int] NULL,
	[Motivo] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USERS]

-- %%
/****** Object:  Table [dbo].[USERS]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USERS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[email] [varchar](100) NOT NULL,
	[pass] [varchar](20) NOT NULL,
	[nombre] [varchar](50) NULL,
	[apellido] [varchar](50) NULL,
	[urlImagenPerfil] [varchar](500) NULL,
	[admin] [bit] NOT NULL,
	[fechaNacimiento] [date] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ARTICULOS]

-- %%
SET IDENTITY_INSERT [dbo].[ARTICULOS] ON 
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (1, N'S01', N'Galaxy S10', N'Una canoa cara', 1, 1, N'https://images.samsung.com/is/image/samsung/assets/ar/p6_gro2/p6_initial_mktpd/smartphones/galaxy-s10/specs/galaxy-s10-plus_specs_design_colors_prism_black.jpg?$163_346_PNG$', 80000000.0000, 50, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (2, N'M03', N'Moto G Play 7ma Gen', N'Ya siete de estos?', 5, 1, N'https://imei24.com/img/motorola/11_29_11_motorola-moto-g7-play-32gb-dual-sim-blue.jpg', 80000000.0000, 30, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (3, N'S99', N'Play 4', N'Ya no se cuantas versiones hay', 3, 3, N'https://pixelstore.com.ar/wp-content/uploads/2019/05/Playstation.jpg', 5000.0000, 15, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (4, N'S56', N'Bravia 55', N'Alta tele', 3, 2, N'https://intercompras.com/product_thumb_keepratio_2.php?img=images/product/SONY_KDL-55W950A.jpg&w=650&h=450', 1000000.0000, 0, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (5, N'A23', N'Apple TV', N'lindo loro', 2, 3, N'https://store.storeimages.cdn-apple.com/4668/as-images.apple.com/is/rfb-apple-tv-4k?wid=1144&hei=1144&fmt=jpeg&qlt=80&.v=1513897159574', 7850.0000, 10, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (11, N'a15', N'tralaleo tralala', N'a veces gana a veces pierde', 4, 4, N'https://images.cults3d.com/Tgm8B-8tZ_QGa-D5fQWw_iKFTK8=/516x516/filters:no_upscale()/https://fbi.cults3d.com/uploaders/38055520/illustration-file/b00d517e-0d7d-444e-b3a7-d438fc795372/trataCapture.png', 50000.0000, 25, NULL, CAST(25000.00 AS Decimal(18, 2)), NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (12, N'a5r2', N'cocodrillo bombardino', N'pierde vs tralaleo tralala', 1, 3, N'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTQsbM0TfOh9FmV6rrbYv57xKAlWLn01IGaew&s', 50000.0000, 75, NULL, CAST(40000.00 AS Decimal(18, 2)), NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (14, N'a25112', N'Iphone 16 ', N'128 GB Rosa', 4, 1, N'https://icon.co.cr/cdn/shop/files/IMG-14858821_165957f0-2740-4735-b31a-70b3d625088f.jpg?v=1729269514&width=823', 500000.0000, 100, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (15, N'asd12442422', N'Iphone 16 ', N'128 GB ', 1, 1, N'https://compras.tigo.com.co/arquivos/ids/164404-1000-1000/1.png?v=638628829545830000', 5000000.0000, 60, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (16, N'a55222', N'Iphone 15', N'128 GB', 1, 1, N'https://miapplecolombia.com/rails/active_storage/representations/proxy/eyJfcmFpbHMiOnsiZGF0YSI6MTcxMDcxMCwicHVyIjoiYmxvYl9pZCJ9fQ==--c5ec03bbf67945f48aee7d439fee1b898b785555/eyJfcmFpbHMiOnsiZGF0YSI6eyJmb3JtYXQiOiJqcGciLCJyZXNpemVfdG9fZml0IjpbODAwLDgwMF19LCJwdXIiOiJ2YXJpYXRpb24ifX0=--1420d7fd3d20057726f0ef3c0043db24ca0403be/iphone-15-negro-128GB_page-0001.jpg?locale=es', 400000.0000, 5, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (23, N'M503', N'Edge 50 Fusion 5G', N'Carito', 5, 1, N'https://tiendaonline.movistar.com.ar/media/catalog/product/m/o/moto-edge-50-fusion-forestblue-front.png', 1000000.0000, 20, NULL, NULL, NULL)
INSERT [dbo].[ARTICULOS] ([Id], [Codigo], [Nombre], [Descripcion], [IdMarca], [IdCategoria], [ImagenUrl], [Precio], [Stock], [PorcentajeDescuento], [PrecioDescuento], [FechaCreacion]) VALUES (24, N'42a2', N'Televisor Led 55 Pulgadas 4k', N'Televisor Samsung Led 55 Pulgadas 4k Uhd 55ut8050psb', 1, 2, N'https://http2.mlstatic.com/D_Q_NP_992243-MLU78084720626_082024-O.webp', 2000000.0000, 35, NULL, NULL, NULL)
SET IDENTITY_INSERT [dbo].[ARTICULOS] OFF
GO

-- %% [markdown]
-- # [dbo].[CATEGORIAS]

-- %%
SET IDENTITY_INSERT [dbo].[CATEGORIAS] ON 
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (1, N'Celulares')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (2, N'Televisores')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (3, N'Media')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (4, N'Audio')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (5, N'Celulares')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (6, N'Televisores')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (7, N'Media')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (8, N'Audio')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (9, N'Celulares')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (10, N'Televisores')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (11, N'Media')
INSERT [dbo].[CATEGORIAS] ([Id], [Descripcion]) VALUES (12, N'Audio')
SET IDENTITY_INSERT [dbo].[CATEGORIAS] OFF
GO

-- %% [markdown]
-- # [dbo].[MARCAS]

-- %%
SET IDENTITY_INSERT [dbo].[MARCAS] ON 
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (1, N'Samsung')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (2, N'Apple')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (3, N'Sony')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (4, N'Huawei')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (5, N'Motorola')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (6, N'Samsung')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (7, N'Apple')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (8, N'Sony')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (9, N'Huawei')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (10, N'Motorola')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (11, N'Samsung')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (12, N'Apple')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (13, N'Sony')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (14, N'Huawei')
INSERT [dbo].[MARCAS] ([Id], [Descripcion]) VALUES (15, N'Motorola')
SET IDENTITY_INSERT [dbo].[MARCAS] OFF
GO

-- %% [markdown]
-- # [dbo].[USERS]

-- %%
SET IDENTITY_INSERT [dbo].[USERS] ON 
INSERT [dbo].[USERS] ([Id], [email], [pass], [nombre], [apellido], [urlImagenPerfil], [admin], [fechaNacimiento]) VALUES (1, N'admin@admin.com', N'admin', NULL, NULL, NULL, 1, NULL)
INSERT [dbo].[USERS] ([Id], [email], [pass], [nombre], [apellido], [urlImagenPerfil], [admin], [fechaNacimiento]) VALUES (15, N'admin', N'admin', NULL, NULL, NULL, 1, NULL)
INSERT [dbo].[USERS] ([Id], [email], [pass], [nombre], [apellido], [urlImagenPerfil], [admin], [fechaNacimiento]) VALUES (16, N'test', N'test', NULL, NULL, NULL, 0, NULL)
INSERT [dbo].[USERS] ([Id], [email], [pass], [nombre], [apellido], [urlImagenPerfil], [admin], [fechaNacimiento]) VALUES (4, N'user@user.com', N'user', NULL, NULL, NULL, 0, NULL)
INSERT [dbo].[USERS] ([Id], [email], [pass], [nombre], [apellido], [urlImagenPerfil], [admin], [fechaNacimiento]) VALUES (5, N'algo', N'123', N'Ramon', N'Spectrat', N'perfil-5.jpg', 0, CAST(N'1998-01-11' AS Date))
INSERT [dbo].[USERS] ([Id], [email], [pass], [nombre], [apellido], [urlImagenPerfil], [admin], [fechaNacimiento]) VALUES (7, N'agustin198ar@gmail.com', N'asd', NULL, NULL, NULL, 0, NULL)
SET IDENTITY_INSERT [dbo].[USERS] OFF
GO

-- %% [markdown]
-- # [DF__ARTICULOS__Stock__4D5F7D71]

-- %%
ALTER TABLE [dbo].[ARTICULOS] ADD  DEFAULT ((0)) FOR [Stock]
GO

-- %% [markdown]
-- # [DF__ARTICULOS__Fecha__607251E5]

-- %%
ALTER TABLE [dbo].[ARTICULOS] ADD  DEFAULT (getdate()) FOR [FechaCreacion]
GO

-- %% [markdown]
-- # [DF__Movimient__Fecha__51300E55]

-- %%
ALTER TABLE [dbo].[MovimientosStock] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF__USERS__admin__3C69FB99]

-- %%
ALTER TABLE [dbo].[USERS] ADD  DEFAULT ((0)) FOR [admin]
GO

-- %% [markdown]
-- # [FK__Movimient__IdArt__503BEA1C]

-- %%
ALTER TABLE [dbo].[MovimientosStock]  WITH CHECK ADD FOREIGN KEY([IdArticulo])
REFERENCES [dbo].[ARTICULOS] ([Id])
GO

-- %% [markdown]
-- # [dbo].[AltaArticulo]

-- %%
/****** Object:  StoredProcedure [dbo].[AltaArticulo]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AltaArticulo]
    @Codigo NVARCHAR(50),
    @Nombre NVARCHAR(100),
    @Descripcion NVARCHAR(MAX),
    @IdCategoria INT,
    @Precio DECIMAL(18, 2),
    @PrecioDescuento DECIMAL(18, 2),
    @ImagenUrl NVARCHAR(MAX)
AS
BEGIN
    INSERT INTO Articulos (Codigo, Nombre, Descripcion, IdCategoria, Precio, PrecioDescuento, ImagenUrl, FechaCreacion)
    VALUES (@Codigo, @Nombre, @Descripcion, @IdCategoria, @Precio, @PrecioDescuento, @ImagenUrl, GETDATE());
END
GO

-- %% [markdown]
-- # [dbo].[insertarNuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarNuevo]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[insertarNuevo]
@email varchar(50),
@pass varchar(50)
as
insert into USERS (email,pass, admin)output inserted.Id values (@email,@pass, 0)
GO

-- %% [markdown]
-- # [dbo].[MostrarUsuarios]

-- %%
/****** Object:  StoredProcedure [dbo].[MostrarUsuarios]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[MostrarUsuarios]
AS
BEGIN
    SELECT 
        id,
        nombre,
        apellido,
        email,
        urlImagenPerfil,
        admin,
        fechaNacimiento
    FROM USERS;
END
GO

-- %% [markdown]
-- # [dbo].[storedAltaArticulo]

-- %%
/****** Object:  StoredProcedure [dbo].[storedAltaArticulo]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE  [dbo].[storedAltaArticulo]
    @Id INT = 0,
    @Codigo NVARCHAR(50),
    @Nombre NVARCHAR(100),
    @Descripcion NVARCHAR(200),
    @Precio DECIMAL(18,2),
    @PrecioDescuento DECIMAL(18,2),
    @ImagenUrl NVARCHAR(200),
    @IdCategoria INT
AS
BEGIN
    IF @Id = 0
    BEGIN
        INSERT INTO Articulos (Codigo, Nombre, Descripcion, Precio, PrecioDescuento, ImagenUrl, IdCategoria)
        VALUES (@Codigo, @Nombre, @Descripcion, @Precio, @PrecioDescuento, @ImagenUrl, @IdCategoria)
    END
    ELSE
    BEGIN
        UPDATE Articulos
        SET Codigo = @Codigo,
            Nombre = @Nombre,
            Descripcion = @Descripcion,
            Precio = @Precio,
            PrecioDescuento = @PrecioDescuento,
            ImagenUrl = @ImagenUrl,
            IdCategoria = @IdCategoria
        WHERE Id = @Id
    END
END
GO

-- %% [markdown]
-- # [dbo].[storedListar]

-- %%
/****** Object:  StoredProcedure [dbo].[storedListar]    Script Date: 8/8/2025 19:58:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[storedListar]
AS
SELECT A.Id, A.Codigo, A.Nombre, A.Descripcion,
       C.Descripcion AS Tipo,
       M.Descripcion AS Marcas,
       A.Precio, A.PrecioDescuento,
       A.ImagenUrl, A.IdCategoria, A.IdMarca,
       A.FechaCreacion
FROM ARTICULOS A
INNER JOIN CATEGORIAS C ON A.IdCategoria = C.Id
INNER JOIN MARCAS M ON A.IdMarca = M.Id;
GO

-- %% [markdown]
-- # [CATALOGO_WEB_DB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [CATALOGO_WEB_DB] SET  READ_WRITE 
GO
